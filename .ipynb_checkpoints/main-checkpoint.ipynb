# %% [markdown]
# ## Installing Dependencies

# %%
pip install --upgrade git+https://github.com/mne-tools/mne-python@main
# Out:
# Collecting git+https://github.com/mne-tools/mne-python@main
#   Cloning https://github.com/mne-tools/mne-python (to revision main) to c:\users\imsan\appdata\local\temp\pip-req-build-l683j129
#   Resolved https://github.com/mne-tools/mne-python to commit 8af33df490f94c3dd628cfc23beafed1a6cc6361
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: decorator in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from mne==1.7.0.dev33+g8af33df49) (5.1.0)
# Requirement already satisfied: jinja2 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from mne==1.7.0.dev33+g8af33df49) (3.1.2)
# Collecting lazy-loader>=0.3 (from mne==1.7.0.dev33+g8af33df49)
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from mne==1.7.0.dev33+g8af33df49) (3.8.1)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from mne==1.7.0.dev33+g8af33df49) (1.21.2)
# Requirement already satisfied: packaging in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from mne==1.7.0.dev33+g8af33df49) (21.3)
# Collecting pooch>=1.5 (from mne==1.7.0.dev33+g8af33df49)
#   Downloading pooch-1.8.0-py3-none-any.whl (62 kB)
#                                               0.0/62.7 kB ? eta -:--:--
#      ------                                   10.2/62.7 kB ? eta -:--:--
#      ------------------                     30.7/62.7 kB 435.7 kB/s eta 0:00:01
#      ------------------                     30.7/62.7 kB 435.7 kB/s eta 0:00:01
#      ------------------                     30.7/62.7 kB 435.7 kB/s eta 0:00:01
#      ------------------------               41.0/62.7 kB 163.4 kB/s eta 0:00:01
#      -------------------------------------- 62.7/62.7 kB 197.2 kB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.7.1 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from mne==1.7.0.dev33+g8af33df49) (1.7.2)
# Requirement already satisfied: tqdm in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from mne==1.7.0.dev33+g8af33df49) (4.62.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->mne==1.7.0.dev33+g8af33df49) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->mne==1.7.0.dev33+g8af33df49) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->mne==1.7.0.dev33+g8af33df49) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->mne==1.7.0.dev33+g8af33df49) (1.3.2)
# Requirement already satisfied: pillow>=8 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->mne==1.7.0.dev33+g8af33df49) (8.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->mne==1.7.0.dev33+g8af33df49) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->mne==1.7.0.dev33+g8af33df49) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->mne==1.7.0.dev33+g8af33df49) (6.1.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from pooch>=1.5->mne==1.7.0.dev33+g8af33df49) (3.8.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from pooch>=1.5->mne==1.7.0.dev33+g8af33df49) (2.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from jinja2->mne==1.7.0.dev33+g8af33df49) (2.1.1)
# Requirement already satisfied: colorama in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from tqdm->mne==1.7.0.dev33+g8af33df49) (0.4.6)
# Requirement already satisfied: six in c:\users\imsan\appdata\roaming\python\python39\site-packages (from cycler>=0.10->matplotlib>=3.5.0->mne==1.7.0.dev33+g8af33df49) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.0->mne==1.7.0.dev33+g8af33df49) (3.7.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne==1.7.0.dev33+g8af33df49) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne==1.7.0.dev33+g8af33df49) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne==1.7.0.dev33+g8af33df49) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne==1.7.0.dev33+g8af33df49) (2021.10.8)
# Building wheels for collected packages: mne
#   Building wheel for mne (pyproject.toml): started
#   Building wheel for mne (pyproject.toml): finished with status 'done'
#   Created wheel for mne: filename=mne-1.7.0.dev33+g8af33df49-py3-none-any.whl size=7436172 sha256=791d372da6951117d4979e09e5cc811b7a089143252deb6ee3de69bac7150462
#   Stored in directory: C:\Users\imsan\AppData\Local\Temp\pip-ephem-wheel-cache-70m5dsbf\wheels\05\c1\e9\2e6f76ff93d356267f637b5e6766f967e19c7664f926f06054
# Successfully built mne
# Installing collected packages: lazy-loader, pooch, mne
# Successfully installed lazy-loader-0.3 mne-1.7.0.dev33+g8af33df49 pooch-1.8.0
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/mne-tools/mne-python 'C:\Users\imsan\AppData\Local\Temp\pip-req-build-l683j129'
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Import Libraries

# %%
import mne
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib qt
plt.ion()

# %% [markdown]
# ## Input Data

# %%
sample_data_folder = mne.datasets.sample.data_path()
sample_data_folder
# Out:
# WindowsPath('C:/Users/imsan/mne_data/MNE-sample-data')

# %%
sample_data_raw_file= os.path.join(
    sample_data_folder, "MEG", "sample", "sample_audvis_raw.fif"
)
raw = mne.io.read_raw_fif(sample_data_raw_file)
# Out:
# Opening raw data file C:\Users\imsan\mne_data\MNE-sample-data\MEG\sample\sample_audvis_raw.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 25800 ... 192599 =     42.956 ...   320.670 secs
# Ready.

# %%
print(raw)
# Out:
# <Raw | sample_audvis_raw.fif, 376 x 166800 (277.7 s), ~3.3 MB, data not loaded>

# %%
eeg_and_eog = raw.copy().pick(picks=["eeg", "eog"])
# Out:
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>

# %%
print(eeg_and_eog)
# Out:
# <Raw | sample_audvis_raw.fif, 61 x 166800 (277.7 s), ~3.0 MB, data not loaded>

# %%
print(eeg_and_eog.info)
# Out:
# <Info | 20 non-empty values
#  acq_pars: ACQch001 110113 ACQch002 110112 ACQch003 110111 ACQch004 110122 ...
#  bads: 1 items (EEG 053)
#  ch_names: EEG 001, EEG 002, EEG 003, EEG 004, EEG 005, EEG 006, EEG 007, ...
#  chs: 60 EEG, 1 EOG
#  custom_ref_applied: False
#  description: acquisition (megacq) VectorView system at NMR-MGH
#  dev_head_t: MEG device -> head transform
#  dig: 146 items (3 Cardinal, 4 HPI, 61 EEG, 78 Extra)
#  events: 1 item (list)
#  experimenter: MEG
#  file_id: 4 items (dict)
#  highpass: 0.1 Hz
#  hpi_meas: 1 item (list)
#  hpi_results: 1 item (list)
#  lowpass: 172.2 Hz
#  meas_date: 2002-12-03 19:01:10 UTC
#  meas_id: 4 items (dict)
#  nchan: 61
#  proj_id: 1 item (ndarray)
#  proj_name: test
#  projs: []
#  sfreq: 600.6 Hz
# >

# %%
eeg_raw=eeg_and_eog
eeg_raw.crop(tmax=60).load_data()
eeg_raw.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Channels marked as bad:
# ['EEG 053']

# %%
spectrum = eeg_raw.compute_psd()
spectrum.plot(average=True, picks="data", exclude="bads")
# Out:
# Effective window size : 3.410 (s)
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
midline = ["EEG 002", "EEG 012", "EEG 030", "EEG 048", "EEG 058", "EEG 060"]
spectrum.plot(picks=midline, exclude="bads")
# Out:
# <MNELineFigure size 1000x350 with 2 Axes>

# %%
spectrum.plot_topomap()

# %%
raw.plot_sensors(ch_type="eeg")

# %%
# pick some channels that clearly show heartbeats and blinks
regexp = r"(MEG [12][45][123]1|EEG 00.)"
artifact_picks = mne.pick_channels_regexp(eeg_raw.ch_names, regexp=regexp)
eeg_raw.plot(order=artifact_picks, n_channels=len(artifact_picks), show_scrollbars=False)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Channels marked as bad:
# ['EEG 053']

# %%
from mne.preprocessing import ICA, corrmap, create_ecg_epochs, create_eog_epochs

eog_evoked = create_eog_epochs(eeg_raw).average()
eog_evoked.apply_baseline(baseline=(None, -0.2))
eog_evoked.plot_joint()
# Out:
# Using EOG channel: EOG 061
# EOG channel index for this subject is: [60]
# Filtering the data to remove DC offset to help distinguish blinks from saccades
# Selecting channel EOG 061 for blink detection
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 6007 samples (10.001 s)
#
# Now detecting blinks and generating corresponding events
# Found 10 significant peaks
# Number of EOG events detected: 10
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 10 events and 601 original time points ...
# 0 bad epochs dropped
# Applying baseline correction (mode: mean)
# No projector specified for this dataset. Please consider the method self.add_proj.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %%
ica = ICA(n_components=15, max_iter="auto", random_state=97)
ica.fit(eeg_raw)
ica
# Out:
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 25.5s.
# c:\users\imsan\appdata\local\programs\python\python39\lib\site-packages\sklearn\decomposition\_fastica.py:116: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# <ICA | raw data decomposition, method: fastica (fit in 1000 iterations on 36038 samples), 15 ICA components (59 PCA components available), channel types: eeg, no sources marked for exclusion>

# %%
explained_var_ratio = ica.get_explained_variance_ratio(eeg_raw)
for channel_type, ratio in explained_var_ratio.items():
    print(
        f"Fraction of {channel_type} variance explained by all components: " f"{ratio}"
    )
# Out:
# Fraction of eeg variance explained by all components: 0.9863587722436372

# %%
explained_var_ratio = ica.get_explained_variance_ratio(
    eeg_raw, components=[0], ch_type="eeg"
)
# This time, print as percentage.
ratio_percent = round(100 * explained_var_ratio["eeg"])
print(
    f"Fraction of variance in EEG signal explained by first component: "
    f"{ratio_percent}%"
)
# Out:
# Fraction of variance in EEG signal explained by first component: 93%

# %%
eeg_raw.load_data()
ica.plot_sources(raw, show_scrollbars=False)
# Out:
# Creating RawArray with float64 data, n_channels=16, n_times=166800
#     Range : 25800 ... 192599 =     42.956 ...   320.670 secs
# Ready.
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
ica.plot_components()
# Out:
# <MNEFigure size 975x731 with 15 Axes>

# %%
# blinks
ica.plot_overlay(eeg_raw, exclude=[0], picks="eeg")
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 59 PCA components

# %%
# ica.apply() changes the Raw object in-place, so let's make a copy first:
reconst_raw = eeg_raw.copy()
ica.apply(reconst_raw)

eeg_raw.plot(order=artifact_picks, n_channels=len(artifact_picks), show_scrollbars=False)
reconst_raw.plot(
    order=artifact_picks, n_channels=len(artifact_picks), show_scrollbars=False
)
del reconst_raw
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 59 PCA components
# Channels marked as bad:
# ['EEG 053']
# Channels marked as bad:
# ['EEG 053']

# %%
ica.exclude = []
# find which ICs match the EOG pattern
eog_indices, eog_scores = ica.find_bads_eog(eeg_raw)
ica.exclude = eog_indices

# barplot of ICA component "EOG match" scores
ica.plot_scores(eog_scores)

# plot diagnostics
ica.plot_properties(eeg_raw, picks=eog_indices)

# plot ICs applied to raw data, with EOG matches highlighted
ica.plot_sources(eeg_raw, show_scrollbars=False)

# plot ICs applied to the averaged EOG epochs, with EOG matches highlighted
ica.plot_sources(eog_evoked)
# Out:
# Using EOG channel: EOG 061
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 6007 samples (10.001 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 6007 samples (10.001 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=16, n_times=36038
#     Range : 25800 ... 61837 =     42.956 ...   102.956 secs
# Ready.

# %%
eeg_raw.set_eeg_reference('average')
eeg_raw.notch_filter(50)
ica = mne.preprocessing.ICA(n_components=0.95)
ica.fit(eeg_raw)

# Define frequency bands
bands = {
    'delta': (0.5, 4),
    'theta': (4, 8),
    'alpha': (8, 12),
    'beta': (12, 30),
    'gamma': (30, 100),
}

                   

# peak-to-peak amplitude rejection parameters
reject = dict(mag=4e-12)



# Compute PSD
psds = {band: mne.time_frequency.psd_multitaper(epochs) for band, epochs in filtered_epochs.items()}

# Plot PSD
mne.viz.plot_psd(psds)
# Out:
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3965 samples (6.602 s)
#
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:    0.0s finished
# Selecting by explained variance: 17 components
# Fitting ICA took 0.9s.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8584\2926115209.py in <module>
#      21
#      22 # Compute PSD
# ---> 23 psds = {band: mne.time_frequency.psd_multitaper(epochs) for band, epochs in filtered_epochs.items()}
#      24
#      25 # Plot PSD
#
# NameError: name 'filtered_epochs' is not defined

# %% [markdown]
# ## Data Preprocessing

# %%
# Apply baseline correction
raw.set_eeg_reference('average')
raw.apply_baseline((None, 0.5))

# Apply a notch filter to remove 50 Hz power line noise
raw.notch_filter(50)

# Apply ICA (Independent Component Analysis) to remove artifacts
ica = mne.preprocessing.ICA(n_components=0.95)
ica.fit(raw)
ica.plot_components()

# Select components to exclude (e.g., eye blinks)
ica.exclude = [1, 2]  # Replace with actual component indices

# Apply ICA to remove selected components
raw = raw.apply_ica(ica)

# %% [markdown]
# ## Visualization

# %%
# Plot the raw EEG data
plot_raw(raw)

# Plot the power spectrum density (PSD) for each EEG channel
plot_psd(raw, picks=eeg_channels)

# Extract epochs for different mind activities (e.g., rest, task1, task2)
epochs_rest = mne.Epochs(raw, picks=eeg_channels, events=rest_events, tmin=-0.2, tmax=1.0)
epochs_task1 = mne.Epochs(raw, picks=eeg_channels, events=task1_events, tmin=-0.2, tmax=1.0)
epochs_task2 = mne.Epochs(raw, picks=eeg_channels, events=task2_events, tmin=-0.2, tmax=1.0)

# Plot the averaged epochs for each condition
epochs_rest.average().plot(time_unit='s')
epochs_task1.average().plot(time_unit='s')
epochs_task2.average().plot(time_unit='s')

# Plot the PSD of averaged epochs for each condition
plot_epochs_psd_topomap(epochs_rest.average(), ch_type='eeg')
plot_epochs_psd_topomap(epochs_task1.average(), ch_type='eeg')
plot_epochs_psd_topomap(epochs_task2.average(), ch_type='eeg')
